# %% [markdown]
# # Test Experiment
#
# This is a test notebook for the smart-learn platform.

# %%
print("Hello, Smart Learn!")
# Out:
# Hello, Smart Learn!

# %%
# Simple calculation
result = sum(range(1, 6))
result
# Out:
# 15
